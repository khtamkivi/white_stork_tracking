# %% [markdown]
# ### .txt file to .csv file

# %% [markdown]
# Reading in the the average land temperature data from a .txt file of Berkeley university.

# %%
import csv

input_file = 'data/land_average_temp.txt'
output_file = 'data/land_average_temp.csv'

# %%
with open(input_file, 'r') as file:
    lines = file.readlines()

#Identifying the start of the table
start_index = None
for i, line in enumerate(lines):
    if line.strip().startswith('% Year, Month,  Anomaly, Unc.,'):
        start_index = i + 1
        break

#Ensure we found the start of the table
if start_index is None:
    raise ValueError("Start of the data table not found.")

# %%
with open(output_file, 'w', newline = '') as csvfile:
    writer = csv.writer(csvfile)

    #Write the header
    header = ['year', 'month', 'monthly_anomaly', 'monthly_unc', 
              'annual_anomaly', 'annual_unc', 'five_year_anomaly', 'five_year_unc', 
              'ten_year_anomaly', 'ten_year_unc', 'twenty_year_anomaly', 'twenty_year_unc']
    
    writer.writerow(header)

    #Write the data
    for line in lines[start_index:]:
        data = line.split()
        if data:
            writer.writerow(data)

# %% [markdown]
# ### Reading in and modifying the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
temp_data = pd.read_csv('data/land_average_temp.csv')

# %%
temp_data.head()
# Out:
#    year  month  monthly_anomaly  monthly_unc  annual_anomaly  annual_unc  \
# 0  1750      1           -0.782        3.508             NaN         NaN
# 1  1750      2           -1.431        3.889          -1.050       0.863
# 2  1750      3            0.002        2.220          -1.076       0.867
# 3  1750      4           -0.314        1.265          -1.108       0.868
# 4  1750      5           -1.732        3.448          -1.426       0.878
#
#    five_year_anomaly  five_year_unc  ten_year_anomaly  ten_year_unc  \
# 0                NaN            NaN               NaN           NaN
# 1                NaN            NaN               NaN           NaN
# 2                NaN            NaN               NaN           NaN
# 3                NaN            NaN               NaN           NaN
# 4                NaN            NaN               NaN           NaN
#
#    twenty_year_anomaly  twenty_year_unc
# 0                  NaN              NaN
# 1                  NaN              NaN
# 2                  NaN              NaN
# 3                  NaN              NaN
# 4                  NaN              NaN

# %% [markdown]
# Strok migration data contains data from years 1995 - 2015 and thus temperature data from all other years is irrelevant. For the sake of visualisations, data from years 1985-2023 is kept.

# %%
temp_data_range = temp_data[temp_data['year'].isin(range(1985,2024))]

# %% [markdown]
# Now we need an average annual temperature anomaly value for each year.

# %%
annual_averages = temp_data_range.groupby('year')['annual_anomaly'].mean().reset_index()

# %%
plt.figure(figsize=(10, 6))

plt.plot(annual_averages['year'], annual_averages['annual_anomaly'], linestyle='--', color='k', linewidth = 1)

#Overlaying the 1995-2014 range with a solid line
data_1995_2014 = annual_averages[(annual_averages['year'] >= 1995) & (annual_averages['year'] <= 2014)]
plt.plot(data_1995_2014['year'], data_1995_2014['annual_anomaly'], linestyle='-', color='red', label='Migration Data Range')

plt.xlabel('')
plt.ylabel('Average Temperature Anomaly')
plt.title('Yearly Average Land Temperature Anomaly\n1985-2023')

plt.legend()

plt.show()

# %%
#annual_averages.to_csv('data/annual_avg_temp.csv')
